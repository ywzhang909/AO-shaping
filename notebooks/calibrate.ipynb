# %%
import pandas as pd
import numpy as np
from scipy.io import loadmat
from scipy.ndimage import center_of_mass

import tqdm

import matplotlib.pylab as plt
from matplotlib.patches import Circle

# %%
# load matlab mat data
mat1 = np.loadtxt("../data/calibration/Wave_9.txt").reshape(360, 360)

plt.imshow(mat1)
# plt.plot(center_of_mass(mat1))

# %%
center_of_mass(mat1)
# Out:
# (np.float64(1486134.9439588136), np.float64(-5886719.686552441))
